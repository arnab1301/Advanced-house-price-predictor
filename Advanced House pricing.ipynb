# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.read_csv("train.csv")
pd.pandas.set_option('display.max_columns',None)

# %%
data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
features_null=[features for features in data.columns if data[features].isnull().sum()>=1]
features_null
# Out:
# ['LotFrontage',
#  'Alley',
#  'MasVnrType',
#  'MasVnrArea',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Electrical',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PoolQC',
#  'Fence',
#  'MiscFeature']

# %%
for features in features_null:
    print(features,data[features].isnull().sum())
# Out:
# LotFrontage 259
# Alley 1369
# MasVnrType 8
# MasVnrArea 8
# BsmtQual 37
# BsmtCond 37
# BsmtExposure 38
# BsmtFinType1 37
# BsmtFinType2 38
# Electrical 1
# FireplaceQu 690
# GarageType 81
# GarageYrBlt 81
# GarageFinish 81
# GarageQual 81
# GarageCond 81
# PoolQC 1453
# Fence 1179
# MiscFeature 1406

# %%
for feature in features_null:
    dataset=data.copy()
    dataset[feature]=np.where(dataset[feature].isnull(),1,0)
    dataset.groupby(feature)['SalePrice'].median().plot.bar()
    plt.title(feature)
    plt.show()

# %%
print("number of ID's is {}".format(len(data.Id)))
# Out:
# number of ID's is 1460

# %%
numerical_var=[feature for feature in data.columns if data[feature].dtypes != 'O']

# %%
len(numerical_var)
# Out:
# 38

# %%
year_var=[f for f in data.columns if 'Yr' in f or 'Year' in f]
year_var
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
for feature in year_var:
    print(feature, data[feature].unique())
# Out:
# YearBuilt [2003 1976 2001 1915 2000 1993 2004 1973 1931 1939 1965 2005 1962 2006
#  1960 1929 1970 1967 1958 1930 2002 1968 2007 1951 1957 1927 1920 1966
#  1959 1994 1954 1953 1955 1983 1975 1997 1934 1963 1981 1964 1999 1972
#  1921 1945 1982 1998 1956 1948 1910 1995 1991 2009 1950 1961 1977 1985
#  1979 1885 1919 1990 1969 1935 1988 1971 1952 1936 1923 1924 1984 1926
#  1940 1941 1987 1986 2008 1908 1892 1916 1932 1918 1912 1947 1925 1900
#  1980 1989 1992 1949 1880 1928 1978 1922 1996 2010 1946 1913 1937 1942
#  1938 1974 1893 1914 1906 1890 1898 1904 1882 1875 1911 1917 1872 1905]
# YearRemodAdd [2003 1976 2002 1970 2000 1995 2005 1973 1950 1965 2006 1962 2007 1960
#  2001 1967 2004 2008 1997 1959 1990 1955 1983 1980 1966 1963 1987 1964
#  1972 1996 1998 1989 1953 1956 1968 1981 1992 2009 1982 1961 1993 1999
#  1985 1979 1977 1969 1958 1991 1971 1952 1975 2010 1984 1986 1994 1988
#  1954 1957 1951 1978 1974]
# ...

# %%
data.groupby('YrSold')['SalePrice'].median().plot()
plt.xlabel('Yr Sold')
plt.ylabel('Sale Price')
# Out:
# Text(0, 0.5, 'Sale Price')

# %%
for feature in year_var:
    dataset=data.copy()
        
    dataset[feature]=dataset['YrSold']-dataset['YearBuilt']
    plt.scatter(dataset[feature],dataset['SalePrice'],c='purple')
    plt.xlabel('Age of House')
    plt.ylabel('Sale Price')

# %%
for feature in year_var:
    if feature!='YrSold':
        dataset=data.copy()    
        
        dataset[feature]=dataset['YrSold']-dataset[feature]
        
        plt.scatter(dataset[feature],dataset['SalePrice'],c='purple')
        plt.xlabel(feature)
        plt.ylabel('Sale Price')
        plt.show()

# %%
discrete_feature=[features for features in numerical_var if len(dataset[features].unique())<25 and features not in year_var+['Id']]
len(discrete_feature)
# Out:
# 17

# %%
for feature in discrete_feature:
    dataset=data.copy()
    dataset.groupby(feature)['SalePrice'].median().plot.bar()
    plt.xlabel(feature)
    plt.ylabel('Sale Price')
    plt.show()

# %%
conti_feature=[features for features in numerical_var if len(dataset[features].unique())>25 and features not in year_var+['Id']]
len(conti_feature)
# Out:
# 16

# %%
for feature in conti_feature:
    dataset=data.copy()
    dataset[feature].hist(bins=40)
    plt.xlabel(feature)
    plt.ylabel('count')
    plt.show()

# %%
#performing logarithmic transformation

for feature in conti_feature:
    dataset=data.copy()
    if 0 in dataset[feature].unique():
        pass
    else:
        dataset[feature]=np.log(dataset[feature])
        dataset['SalePrice']=np.log(dataset['SalePrice'])
        plt.scatter(dataset[feature],dataset['SalePrice'])
        plt.xlabel(feature)
        plt.ylabel('SalePrice')
        plt.title(feature)
        plt.show()

# %%
for feature in conti_feature:
    if 0 in dataset[feature].unique():
        print(feature)
# Out:
# MasVnrArea
# BsmtFinSF1
# BsmtFinSF2
# BsmtUnfSF
# TotalBsmtSF
# 2ndFlrSF
# GarageArea
# WoodDeckSF
# OpenPorchSF
# EnclosedPorch
# ScreenPorch

# %%
for feature in conti_feature:
    dataset=data.copy()
    if 0 in dataset[feature].unique():
        pass
    else:
        dataset[feature]=np.log(dataset[feature])
        dataset.boxplot(column=feature)
        ##plt.xlabel(feature)
        ##plt.ylabel(feature)
        plt.title(feature)
        plt.show()

# %%
categorical_var=[feature for feature in data.columns if data[feature].dtypes=='O']
len(categorical_var)
# Out:
# 43

# %%
for feature in categorical_var:
    print(feature , len(data[feature].unique()))
# Out:
# MSZoning 5
# Street 2
# Alley 3
# LotShape 4
# LandContour 4
# Utilities 2
# LotConfig 5
# LandSlope 3
# Neighborhood 25
# Condition1 9
# Condition2 8
# BldgType 5
# HouseStyle 8
# RoofStyle 6
# RoofMatl 8
# Exterior1st 15
# Exterior2nd 16
# MasVnrType 5
# ExterQual 4
# ExterCond 5
# Foundation 6
# BsmtQual 5
# BsmtCond 5
# BsmtExposure 5
# BsmtFinType1 7
# BsmtFinType2 7
# Heating 6
# HeatingQC 5
# CentralAir 2
# Electrical 6
# KitchenQual 4
# Functional 7
# FireplaceQu 6
# GarageType 7
# GarageFinish 4
# GarageQual 6
# GarageCond 6
# PavedDrive 3
# PoolQC 4
# Fence 5
# MiscFeature 5
# SaleType 9
# SaleCondition 6

# %%
for feature in categorical_var:
    dataset=data.copy()
    dataset.groupby(feature)['SalePrice'].median().plot.bar()
    plt.xlabel(feature)
    plt.ylabel('Sale Price')
    plt.show()
